# %%
library(SingleR)
library(S4Vectors)
library(ggpubr)
source("https://raw.githubusercontent.com/nyuhuyang/SeuratExtra/master/R/Seurat3_functions.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     space
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
# Loading required package: slam
#
# Loading required package: sparsesvd

# %%
singlerDF = readRDS("../output/20200915_singleR_pred.rds")

# %%
singlerDF
# Out:
# DataFrame with 47423 rows and 5 columns
#                                                                              scores
#                                                                            <matrix>
# AAACCCAAGCACGGAT-1-0-0    0.310368406622891:0.156670143892473:0.262957666062234:...
# AAACCCAAGGACGCAT-1-0-0    0.228085115061736:0.162988641541855:0.280307334367524:...
# AAACCCAAGGGCGAAG-1-0-0    0.335479677248591:0.154638294339845:0.284896093093823:...
# AAACCCACAATACCTG-1-0-0   0.258031046421754:0.273955250202148:0.0967426332897624:...
# AAACCCACAATCCTAG-1-0-0    0.213102384845222:0.156008678951511:0.277915478417207:...
# ...                                                                             ...
# TTTGTTGCAAGTTGGG-1-17-17  0.344999637764735:0.273874669254508:0.160959955343446:...
# TTTGTTGCACTTGGCG-1-17-17   0.46215637372509:0.546922099422801:0.177738386126234:...
# TTTGTTGGTAGCTCGC-1-17-17 0.196642280733386:0.230202932798216:0.0429421824052991:...
# TTTGTTGGTCGCTTAA-1-17-17   0.2633400698505:0.292756341459738:0.0941781795661536:...
# TTTGTTGTCTCACGAA-1-17-17  0.366151158593983:0.443417355104559:0.100634055508464:...
#                                 first.labels
#                                  <character>
# AAACCCAAGCACGGAT-1-0-0             Monocytes
# AAACCCAAGGACGCAT-1-0-0              NK cells
# AAACCCAAGGGCGAAG-1-0-0             Monocytes
# AAACCCACAATACCTG-1-0-0           Fibroblasts
# AAACCCACAATCCTAG-1-0-0   T cells, CD4+, Th17
# ...                                      ...
# TTTGTTGCAAGTTGGG-1-17-17   Endothelial cells
# TTTGTTGCACTTGGCG-1-17-17         Fibroblasts
# TTTGTTGGTAGCTCGC-1-17-17        Chondrocytes
# TTTGTTGGTCGCTTAA-1-17-17         Fibroblasts
# TTTGTTGTCTCACGAA-1-17-17         Fibroblasts
#                                                 tuning.scores
#                                                   <DataFrame>
# AAACCCAAGCACGGAT-1-0-0   0.507970022771561:0.0509647388954404
# AAACCCAAGGACGCAT-1-0-0    0.235142282337409:0.059322834649257
# AAACCCAAGGGCGAAG-1-0-0    0.312187203779327:0.232398513334995
# AAACCCACAATACCTG-1-0-0    0.254911046125748:0.165154536594322
# AAACCCACAATCCTAG-1-0-0    0.224399114069728:0.222272274261208
# ...                                                       ...
# TTTGTTGCAAGTTGGG-1-17-17  0.180867980819119:0.176590303478301
# TTTGTTGCACTTGGCG-1-17-17  0.375073237238455:0.282749217367287
# TTTGTTGGTAGCTCGC-1-17-17  0.226714207408271:0.221641357216225
# TTTGTTGGTCGCTTAA-1-17-17 0.244494795961946:0.0492486171643916
# TTTGTTGTCTCACGAA-1-17-17 0.259971095903725:0.0523088663807642
#                                       labels       pruned.labels
#                                  <character>         <character>
# AAACCCAAGCACGGAT-1-0-0             Monocytes           Monocytes
# AAACCCAAGGACGCAT-1-0-0              NK cells            NK cells
# AAACCCAAGGGCGAAG-1-0-0             Monocytes           Monocytes
# AAACCCACAATACCTG-1-0-0           Fibroblasts         Fibroblasts
# AAACCCACAATCCTAG-1-0-0   T cells, CD4+, Th17 T cells, CD4+, Th17
# ...                                      ...                 ...
# TTTGTTGCAAGTTGGG-1-17-17          Adipocytes          Adipocytes
# TTTGTTGCACTTGGCG-1-17-17         Fibroblasts         Fibroblasts
# TTTGTTGGTAGCTCGC-1-17-17        Chondrocytes        Chondrocytes
# TTTGTTGGTCGCTTAA-1-17-17         Fibroblasts         Fibroblasts
# TTTGTTGTCTCACGAA-1-17-17         Fibroblasts         Fibroblasts

# %%
as.data.frame(table(singlerDF$labels))
# Out:
#    Var1                             Freq
# 1  Adipocytes                       1509
# 2  Astrocytes                        584
# 3  B cells, naive                   1315
# 4  Chondrocytes                      154
# 5  CLP                              1177
# 6  CMP                                49
# 7  DC                                205
# 8  Endothelial cells                 234
# 9  Eosinophils                       122
# 10 Epithelial cells                 2856
# 11 Erythrocytes                      387
# 12 Fibroblasts                      4691
# 13 GMP                                22
# 14 HSC                                59
# 15 Keratinocytes                     290
# 16 Macrophages                      4030
# 17 Macrophages M1                    179
# 18 Macrophages M2                      9
# 19 Megakaryocytes                    116
# 20 Melanocytes                        17
# 21 MEP                               342
# 22 Mesangial cells                   277
# 23 Monocytes                        6741
# 24 Monocytes, CD14+                   46
# 25 Monocytes, CD16+                   50
# 26 MPP                                26
# 27 mv Endothelial cells              764
# 28 Myocytes                          256
# 29 Neurons                           787
# 30 Neutrophils                       130
# 31 NK cells                         3535
# 32 Pericytes                         193
# 33 Plasma cells                     1098
# 34 Preadipocytes                       3
# 35 Skeletal muscle                   204
# 36 Smooth muscle                      28
# 37 T cells, CD4+, memory TREG       3021
# 38 T cells, CD4+, naive             1364
# 39 T cells, CD4+, naive TREG         356
# 40 T cells, CD4+, naive, stimulated  127
# 41 T cells, CD4+, TFH               1240
# 42 T cells, CD4+, Th1               3913
# 43 T cells, CD4+, Th1_17            1085
# 44 T cells, CD4+, Th17               985
# 45 T cells, CD4+, Th2                848
# 46 T cells, CD8+, naive             1126
# 47 T cells, CD8+, naive, stimulated  873

# %%
table(grepl("NK|T cells", singlerDF$labels))
# Out:
# FALSE  TRUE
# 28950 18473

# %%
T_NK <- grepl("NK|T cells", singlerDF$labels)
T_NK_df <- singlerDF[T_NK,]

# %%
T_NK_summary <- as.data.frame(table(T_NK_df$labels))

# %%
colnames(T_NK_summary)= c("cell_type", "cell_number")

# %%
T_NK_summary[,"cell_type_cell_number"] = paste(T_NK_summary$cell_type,":", T_NK_summary$cell_number)

# %%
options(repr.plot.width=10, repr.plot.height=7)

ggpie(T_NK_summary, "cell_number", label = "cell_type_cell_number",
      fill = "cell_type", color = "white",
   palette = singler.colors)
# Out:
# plot without title

# %%
adata = sc.read_h5ad("../output/20200729_SCT.h5ad")
# Out:
# Error in sc.read_h5ad("../output/20200729_SCT.h5ad"): could not find function "sc.read_h5ad"
# Traceback:

# %%
adata = sc.read_h5ad("../output/20200914_BladderCancerImmune.h5ad")
